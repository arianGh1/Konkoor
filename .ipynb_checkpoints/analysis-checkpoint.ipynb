# %%
import pandas as pd
from ast import literal_eval
from dython import nominal
import matplotlib.pyplot as plt
import seaborn as sns
from bidi.algorithm import get_display
from arabic_reshaper import reshape
import numpy as np
import pickle
import warnings
import pickle
import matplotlib

import matplotlib.pyplot as plt
import matplotlib.animation as animation
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
from matplotlib.animation import FuncAnimation

# %%
df = pd.read_csv("final.csv")

# %%
df
# Out:
#              شهر  رتبه کشوری  رتبه در منطقه    منطقه  سابقه کانونی  \
# 0          تهران           1            1.0  منطقه 1             3
# 1        رفسنجان           2            1.0  منطقه 2             6
# 2           اراك           3            2.0  منطقه 2             7
# 3           اراك           5            4.0  منطقه 2             3
# 4           مشهد           6            2.0  منطقه 1             1
# ...          ...         ...            ...      ...           ...
# 73833     كنگاور        3565          990.0  منطقه 3             2
# 73834  رباط كريم        3586          995.0  منطقه 3             7
# 73835     اشنويه        3596          999.0  منطقه 3             3
# 73836       گنبد        3596          999.0  منطقه 3             3
# 73837      گرگان        3596          999.0  منطقه 3             1
#
#        میانگین تراز کانون  تعداد آزمون                 رشته قبولی  \
# 0                    7738         72.0            مهندسي کامپيوتر
# 1                    7857        120.0            مهندسي کامپيوتر
# 2                    7589        142.0            مهندسي کامپيوتر
# 3                    7529         79.0            مهندسي کامپيوتر
# 4                    7645         23.0            مهندسي کامپيوتر
# ...                   ...          ...                        ...
# 73833                6200         69.0                 دندانپزشکي
# 73834                5952        150.0  پزشکي - بورسيه وزارت دفاع
# 73835                6666         64.0         پزشکي - نيمسال دوم
# 73836                6474         60.0                      پزشکي
# 73837                6132         30.0                 دندانپزشکي
#
#                                      دانشگاه قبولی رشته مدرسه   سال
# 0                       دانشگاه صنعتي شريف - تهران      ریاضی  1400
# 1                       دانشگاه صنعتي شريف - تهران      ریاضی  1400
# 2                       دانشگاه صنعتي شريف - تهران      ریاضی  1400
# 3                       دانشگاه صنعتي شريف - تهران      ریاضی  1400
# 4                       دانشگاه صنعتي شريف - تهران      ریاضی  1400
# ...                                            ...        ...   ...
# 73833                     دانشگاه علوم پزشکي ايلام      تجربی  1400
# 73834  دانشگاه علوم پزشکي ارتش جمهوري اسلامي ايران      تجربی  1400
# 73835                    دانشگاه علوم پزشکي اروميه      تجربی  1400
# 73836                      دانشگاه علوم پزشکي بابل      تجربی  1400
# 73837                     دانشگاه علوم پزشکي بوشهر      تجربی  1400
#
# [73838 rows x 11 columns]

# %%
with open("dic_toprov","rb") as f:
    dic = pickle.load(f)

# %%
alt_dic = {
    "یاسوج":"کهگیلویه و بویراحمد",
    "گنبد":"گلستان",
    "اسلام شهر":"تهران",
    "قائن":"خراسان جنوبی",
    "شهر قدس":"تهران",
    "هشتگرد":"البرز",
    "دهدشت":"کهگیلویه و بویراحمد",
    "برازجان":"بوشهر",
    "نورآباد ممسنی":"فارس",
    "مشکین شهر":"اردبیل",
    "ماه شهر":"خوزستان",
    "پارس آباد مغان":"اردبیل",
    "بندر دیر":"بوشهر",
    "شاهین شهر":"اصفهان",
    "در گز":"خراسان رضوی",
    "آشخانه":"خراسان شمالی",
    "اسلام آبادغرب":"کرمانشاه",
    "نورآباد":"لرستان",
    "امیرکلا":"مازندران",
    "شوش دانیال":"خوزستان",
    "خورموج":"بوشهر",
    "قره ضیاءالدین":"آذربایجان غربی",
    "تیران":"اصفهان",
    "بندرترکمن":"گلستان",
    "فریدون کنار":"مازندران",
    "محمدیه":"قزوین",
    "تهرانسر":"تهران",
    "علی آبادکتول":"گلستان",
    "ایوان غرب":"ایلام",
    "شازنداراک":"مرکزی",
    "فیض آبادتربت حیدریه":"خراسان رضوی",
    "الشتر":"لرستان",
    "فولاد شهر":"اصفهان"
}

# %%
with open("dic_population","rb") as f:
    dic_population = pickle.load(f)

# %%
df1 = df.copy()

# %%
for key in dic.keys():
    key = key.replace("\u200c"," ").replace("ك","").replace("ي","ی")

# %%
df1["شهر"] = df1["شهر"].apply(lambda x: x.replace("\u200c"," ").strip())
df1["شهر"] = df1["شهر"].apply(lambda x: x.replace("ك","ک").replace("ي","ی"))

# %%
dic_final = dict(dic.items()|alt_dic.items())

# %%
df1["استان"] = df1["شهر"].apply(lambda x: dic_final[x].strip().replace("\u200c"," ") if x in dic_final.keys() else None)

# %%
df1 = df1.dropna()
df1 = df1.reset_index(drop=True)

# %%
df3 = df1.copy()

# %%
df3 = df3[df3["رتبه کشوری"]<=1000]
df3 = df3.reset_index(drop=True)

# %%
df3
# Out:
#            شهر  رتبه کشوری  رتبه در منطقه       منطقه  سابقه کانونی  \
# 0        تهران           1            1.0     منطقه 1             3
# 1      رفسنجان           2            1.0     منطقه 2             6
# 2         اراک           3            2.0     منطقه 2             7
# 3         اراک           5            4.0     منطقه 2             3
# 4         مشهد           6            2.0     منطقه 1             1
# ...        ...         ...            ...         ...           ...
# 22648      رشت         989          441.0     منطقه 2             1
# 22649    تهران         997          322.0     منطقه 1             2
# 22650      نور         997          446.0     منطقه 2             2
# 22651     بانه         999          230.0     منطقه 3             1
# 22652  عجب شیر        1000           98.0  ايثارگر-5%             5
#
#        میانگین تراز کانون  تعداد آزمون          رشته قبولی  \
# 0                    7738         72.0     مهندسي کامپيوتر
# 1                    7857        120.0     مهندسي کامپيوتر
# 2                    7589        142.0     مهندسي کامپيوتر
# 3                    7529         79.0     مهندسي کامپيوتر
# 4                    7645         23.0     مهندسي کامپيوتر
# ...                   ...          ...                 ...
# 22648                6902         23.0          دندانپزشکي
# 22649                6476         37.0  پزشکي - نيمسال اول
# 22650                6556         47.0  پزشکي - نيمسال دوم
# 22651                6255         25.0  پزشکي - نيمسال اول
# 22652                5971        102.0  پزشکي - نيمسال دوم
#
#                             دانشگاه قبولی رشته مدرسه   سال           استان
# 0              دانشگاه صنعتي شريف - تهران      ریاضی  1400           تهران
# 1              دانشگاه صنعتي شريف - تهران      ریاضی  1400           کرمان
# 2              دانشگاه صنعتي شريف - تهران      ریاضی  1400           مرکزی
# 3              دانشگاه صنعتي شريف - تهران      ریاضی  1400           مرکزی
# 4              دانشگاه صنعتي شريف - تهران      ریاضی  1400     خراسان رضوی
# ...                                   ...        ...   ...             ...
# 22648  دانشگاه علوم پزشکي كردستان - سنندج      تجربی  1400           گیلان
# 22649            دانشگاه علوم پزشکي تبريز      تجربی  1400           تهران
# 22650           دانشگاه علوم پزشکي اصفهان      تجربی  1400        مازندران
# 22651            دانشگاه علوم پزشکي تبريز      تجربی  1400         کردستان
# 22652            دانشگاه علوم پزشکي تبريز      تجربی  1400  آذربایجان شرقی
#
# [22653 rows x 12 columns]

# %%
# Make a plot based on provinces performance regarding to this decade
for_plot = pd.DataFrame()

# Preparing a dataframe for ease of usage in plots
for i in range(1391,1401):
    sample = df3[df3["سال"]==i]
    grouped = sample[["استان","رتبه کشوری","سال"]].groupby(["استان","سال"]).count()
    grouped["رتبه کشوری"] = grouped["رتبه کشوری"]
    grouped = grouped.reset_index()
    for_plot["استان"] = grouped["استان"]
    for_plot[str(i)] = grouped["رتبه کشوری"]

# %%
cols = [str(col) for col in range(1391,1401)]

for_heat = for_plot.rename(columns={"استان":"Province"})

for index in range(31):
    for col in cols:
        for_heat.at[index,col] = (for_heat.at[index,col]/dic_population[for_heat.at[index,"Province"]])*7800
for_heat["Province"] = for_heat["Province"].apply(lambda x: get_display(reshape(x)))
for_heat = for_heat.set_index(["Province"])
fig,ax = plt.subplots(figsize=(15,15),facecolor = plt.cm.Greys(0.2),dpi = 150,tight_layout=True)
sns.heatmap(for_heat[cols], cmap="YlGnBu",annot=True);
fig.savefig("exports/heatmap.png",bbox_inches='tight',dpi=300)

# %%
### Lets make color dictionary in order to specify unique color for each province
names = list(for_plot["استان"])
color_dic = {}
for index,name in enumerate(names):
    if index%6 == 0:
        color_dic[name] = "red"
    elif index%9==1:
        color_dic[name]= "purple"
    elif index%9==2:
        color_dic[name]= "blue"
    elif index%9==3:
        color_dic[name]= "green"
    elif index%9==4:
        color_dic[name]= "gray"
    elif index%9==5:
        color_dic[name]= "yellow"
    elif index%9==6:
        color_dic[name]= "cyan"
    elif index%9==7:
        color_dic[name]= "brown"
    else:
        color_dic[name]= "black"

# %%
# Creating more rows inorder to have smoother plot animation

for_plot = for_plot.T
for_plot.columns = for_plot.iloc[0]
for_plot = for_plot.reset_index()
for_plot = for_plot.drop(labels=0, axis=0)
del for_plot["index"]

expanded = pd.DataFrame([np.nan]*1600)
for col in for_plot.columns:
    expanded[col] = np.nan
del expanded[0]
j=0
for i in range(1600):
     
    if i%160==0:
        expanded.iloc[i] = for_plot.iloc[j]
        j+=1
for_plot = expanded.interpolate()

# %%
j=0
def create_video():
    def update(i):
        glob = globals()
        ax.clear()
        one_row = for_plot.iloc[i]
        one_row_ascending = one_row.sort_values(ascending=True)
        df_rows = pd.DataFrame(one_row_ascending)
        #top_12 = list(df_rows[19:31].index)
        top_12 = list(df_rows[24:31].index)
        colors = []
        for top in top_12:
            colors.append(color_dic[top])
        one_row = one_row[top_12]
        ax.set_facecolor(plt.cm.Greys(0.2))
        [spine.set_visible(False) for spine in ax.spines.values()]
        hbars = ax.barh(y = one_row.rank(),
               tick_label=one_row.index,
               width = one_row.values,
               height = 0.8,
               color = colors
               )
        
        if i%160==0:
            name = get_display(reshape("کنکور"))
            method = get_display(reshape("(عملکرد رتبه های کشوری زیر هزار)"))
            ax.set_title(method+" "+ f'{1388+glob["j"]} '+name)
            glob["j"]+=1
        else:
            name = get_display(reshape("کنکور"))
            method = get_display(reshape("(عملکرد رتبه های کشوری زیر هزار)"))
            ax.set_title(method+" "+f'{1388+glob["j"]} '+name)

        #ax.bar_label(hbars, fmt='%.2d')
        return hbars


    fig,ax = plt.subplots(figsize=(10,7),
                          facecolor = plt.cm.Greys(0.2),
                          dpi = 150,
                          tight_layout=True
                         )

    data_anime = FuncAnimation(
        fig = fig,
        func = update,
        frames= 1600,
        interval=35,
        blit=True
    )
    return data_anime

anim = create_video()
#writer = matplotlib.animation.ImageMagickFileWriter()
anim.save('new.mp4', writer="ffmpeg")

# %%
# Out:
# 0
