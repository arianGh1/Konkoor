# %%
import pandas as pd
import pickle
import numpy as np

# %%
with open("dic_gc1","rb") as f:
    dic_riazi = pickle.load(f)
with open("dic_gc5","rb") as f:
    dic_ensani = pickle.load(f)
with open("dic_gc9","rb") as f:
    dic_zaban = pickle.load(f)

# %%
df_riazi = pd.DataFrame.from_dict(dic_riazi.values())
df_ensani = pd.DataFrame.from_dict(dic_ensani.values())
df_zaban = pd.DataFrame.from_dict(dic_zaban.values())

# %%
frames = [df_riazi,df_ensani,df_zaban]

# %%
df = df.drop_duplicates()
df = df.reset_index(drop=True)

# %%
df = df[~(pd.isnull(df["نام و نام خانوادگی"]))]

# %%
df
# Out:
#          نام و نام خانوادگی        شهر رتبه کشوری رتبه در منطقه    منطقه  \
# 1          علیرضا سخایی راد      اهواز          1             1  منطقه 2
# 2       محمدصادق مجیدی یزدی      تهران          2             1  منطقه 1
# 3               دانا افاضلی      تهران          3
# 4                آریا جلالی    لاهيجان          4             2  منطقه 2
# 5                 علی عباسی     شهركرد          5             3  منطقه 2
# ...                     ...        ...        ...           ...      ...
# 18426            امید جمالی   بندر دير      10784           989  منطقه 3
# 18427           عطا میرزالو        خوي      10820           994  منطقه 3
# 18428            نسرین پروز      ياسوج      10827           995  منطقه 3
# 18429       حسن عظیمی سوران  رباط كريم      10843           998  منطقه 3
# 18430  احسان محمدنژادزیردهی       قرچك      10843           998  منطقه 3
#
#       سابقه کانونی میانگین تراز کانون تعداد آزمون  \
# 1                5               8283          73
# 2                1               8173          11
# 3                1               7585           5
# 4                3               7808          46
# 5                1               7482          17
# ...            ...                ...         ...
# 18426            2               4887          25
# 18427            1               5126          16
# 18428            4               5051          63
# 18429            2               5062          44
# 18430            1               5495          12
#
#                                        رشته قبولی  \
# 1                                      مهندسي برق
# 2                                 مهندسي کامپيوتر
# 3
# 4                                 مهندسي کامپيوتر
# 5                                 مهندسي کامپيوتر
# ...                                           ...
# 18426                                  مهندسي برق
# 18427                             مهندسي کامپيوتر
# 18428  مهندسي کامپيوتر -  بومي کهگيلويه وبويراحمد
# 18429
# 18430                      مهندسي مواد و متالورژي
#
#                              دانشگاه قبولی  gc  year
# 1               دانشگاه صنعتي شريف - تهران   1   100
# 2               دانشگاه صنعتي شريف - تهران   1   100
# 3                                            1   100
# 4               دانشگاه صنعتي شريف - تهران   1   100
# 5               دانشگاه صنعتي شريف - تهران   1   100
# ...                                    ...  ..   ...
# 18426                  دانشگاه صنعتي شيراز   1    90
# 18427                       دانشگاه اروميه   1    90
# 18428  دانشگاه تربيت دبير شهيد رجايي_تهران   1    90
# 18429                                        1    90
# 18430     دانشگاه علم و صنعت ايران - تهران   1    90
#
# [18420 rows x 12 columns]
