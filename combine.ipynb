# %%
import pandas as pd

# %%
usef = pd.read_csv("combined.csv")
arian = pd.read_csv("result2.csv")

# %%
del usef["Unnamed: 0"]

# %%
usef
# Out:
#                        نام        شهر  رتبه کشوری  رتبه در منطقه     منطقه  \
# 0                علی محققی      تهران           0           10.0  منطقه يک
# 1            فرناز شهریاری     اصفهان           6            6.0  منطقه يک
# 2          احسان غیاثی نسب       اراك          18            2.0  منطقه دو
# 3      محمدامین شریفی جبلی        كرج          19            3.0  منطقه دو
# 4         ارغوان عبدالملکی      تهران          46            7.0  منطقه دو
# ...                    ...        ...         ...            ...       ...
# 31322      محسن حسین آبادی     كنگاور        3565          990.0   منطقه 3
# 31323       مهدی محمدرضائی  رباط كريم        3586          995.0   منطقه 3
# 31324         احسان قزلباش     اشنويه        3596          999.0   منطقه 3
# 31325           محمد ملائی       گنبد        3596          999.0   منطقه 3
# 31326     محمد الهویی نظری      گرگان        3596          999.0   منطقه 3
#
#        سابقه کانونی  میانگین تراز کانون  تعداد آزمون  \
# ...

# %%
arian
# Out:
#        نام و نام خانوادگی       شهر  رتبه کشوری  رتبه در منطقه     منطقه  \
# 0         محمد پیام تائبی     تهران           1            1.0   منطقه 1
# 1        محمدشایان شعبانی   رفسنجان           2            1.0   منطقه 2
# 2           محمد اسماعیلی      اراك           3            2.0   منطقه 2
# 3         امیرمهدی میقانی      اراك           5            4.0   منطقه 2
# 4          ترانه خسروجردی      مشهد           6            2.0   منطقه 1
# ...                   ...       ...         ...            ...       ...
# 47345      فرشاد ابراهیمی  تربت جام         138            6.0  منطقه سه
# 47346    علی احمدی شاهرخت      قائن         179            7.0  منطقه سه
# 47347       محمدامین شیخی   گچساران         183            8.0  منطقه سه
# 47348      ابوالفضل سیرفر     جيرفت         206            9.0  منطقه سه
# 47349  عمادالدین محرابیان     مهريز         217           10.0  منطقه سه
#
#        سابقه کانونی  میانگین تراز کانون  تعداد آزمون       رشته قبولی  \
# ...

# %%
usef = usef.rename(columns={'سال کنکور': 'سال', 'رشته': 'رشته مدرسه',"نام":"نام و نام خانوادگی"})

# %%
usef
# Out:
#         نام و نام خانوادگی        شهر  رتبه کشوری  رتبه در منطقه     منطقه  \
# 0                علی محققی      تهران           0           10.0  منطقه يک
# 1            فرناز شهریاری     اصفهان           6            6.0  منطقه يک
# 2          احسان غیاثی نسب       اراك          18            2.0  منطقه دو
# 3      محمدامین شریفی جبلی        كرج          19            3.0  منطقه دو
# 4         ارغوان عبدالملکی      تهران          46            7.0  منطقه دو
# ...                    ...        ...         ...            ...       ...
# 31322      محسن حسین آبادی     كنگاور        3565          990.0   منطقه 3
# 31323       مهدی محمدرضائی  رباط كريم        3586          995.0   منطقه 3
# 31324         احسان قزلباش     اشنويه        3596          999.0   منطقه 3
# 31325           محمد ملائی       گنبد        3596          999.0   منطقه 3
# 31326     محمد الهویی نظری      گرگان        3596          999.0   منطقه 3
#
#        سابقه کانونی  میانگین تراز کانون  تعداد آزمون  \
# ...

# %%
final = pd.concat([arian,usef],axis=0)

# %%
final
# Out:
#       نام و نام خانوادگی        شهر  رتبه کشوری  رتبه در منطقه    منطقه  \
# 0        محمد پیام تائبی      تهران           1            1.0  منطقه 1
# 1       محمدشایان شعبانی    رفسنجان           2            1.0  منطقه 2
# 2          محمد اسماعیلی       اراك           3            2.0  منطقه 2
# 3        امیرمهدی میقانی       اراك           5            4.0  منطقه 2
# 4         ترانه خسروجردی       مشهد           6            2.0  منطقه 1
# ...                  ...        ...         ...            ...      ...
# 31322    محسن حسین آبادی     كنگاور        3565          990.0  منطقه 3
# 31323     مهدی محمدرضائی  رباط كريم        3586          995.0  منطقه 3
# 31324       احسان قزلباش     اشنويه        3596          999.0  منطقه 3
# 31325         محمد ملائی       گنبد        3596          999.0  منطقه 3
# 31326   محمد الهویی نظری      گرگان        3596          999.0  منطقه 3
#
#        سابقه کانونی  میانگین تراز کانون  تعداد آزمون  \
# ...

# %%
final = final.dropna()

# %%
final
# Out:
#       نام و نام خانوادگی        شهر  رتبه کشوری  رتبه در منطقه    منطقه  \
# 0        محمد پیام تائبی      تهران           1            1.0  منطقه 1
# 1       محمدشایان شعبانی    رفسنجان           2            1.0  منطقه 2
# 2          محمد اسماعیلی       اراك           3            2.0  منطقه 2
# 3        امیرمهدی میقانی       اراك           5            4.0  منطقه 2
# 4         ترانه خسروجردی       مشهد           6            2.0  منطقه 1
# ...                  ...        ...         ...            ...      ...
# 31322    محسن حسین آبادی     كنگاور        3565          990.0  منطقه 3
# 31323     مهدی محمدرضائی  رباط كريم        3586          995.0  منطقه 3
# 31324       احسان قزلباش     اشنويه        3596          999.0  منطقه 3
# 31325         محمد ملائی       گنبد        3596          999.0  منطقه 3
# 31326   محمد الهویی نظری      گرگان        3596          999.0  منطقه 3
#
#        سابقه کانونی  میانگین تراز کانون  تعداد آزمون  \
# ...

# %%
final = final.reset_index(drop=True)

# %%
final
# Out:
#       نام و نام خانوادگی        شهر  رتبه کشوری  رتبه در منطقه    منطقه  \
# 0        محمد پیام تائبی      تهران           1            1.0  منطقه 1
# 1       محمدشایان شعبانی    رفسنجان           2            1.0  منطقه 2
# 2          محمد اسماعیلی       اراك           3            2.0  منطقه 2
# 3        امیرمهدی میقانی       اراك           5            4.0  منطقه 2
# 4         ترانه خسروجردی       مشهد           6            2.0  منطقه 1
# ...                  ...        ...         ...            ...      ...
# 73833    محسن حسین آبادی     كنگاور        3565          990.0  منطقه 3
# 73834     مهدی محمدرضائی  رباط كريم        3586          995.0  منطقه 3
# 73835       احسان قزلباش     اشنويه        3596          999.0  منطقه 3
# 73836         محمد ملائی       گنبد        3596          999.0  منطقه 3
# 73837   محمد الهویی نظری      گرگان        3596          999.0  منطقه 3
#
#        سابقه کانونی  میانگین تراز کانون  تعداد آزمون  \
# ...

# %%
del final["نام و نام خانوادگی"]
final.to_csv("final.csv",index=False)
